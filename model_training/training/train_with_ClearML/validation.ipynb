# %%
from ultralytics import YOLO

# %%
from ultralytics import settings
settings.update({
    'wandb': False,  # отключает логирование в Weights & Biases
    'hub': False     # отключает Ultralytics HUB
})

# %%
data="/home/jupyter/datasphere/datasets/dataset_uav_fire/data.yaml"

pathToModel1="/home/jupyter/datasphere/project/model_training/train_with_wandb/train2/optimizer=NAdam batch=384 lr0=0.0003 lrf=0.2 cos_lr=True dropout=0.2 warmup_epochs=7 weight_decay=0.01 close_mosaic=5 запуск 2/weights/best.pt"
pathToModel2="/home/jupyter/datasphere/project/model_training/train_with_wandb/train3/тест 13 batch_size=256, optimizer=AdamW ,  lr0=3e-4, lrf=1, weight_decay=0.0005, patience=15, warmup_epochs = 10, warmup_momentum=0.8, dropout=0.2 Остальные параметры по умолчанию/weights/best.pt"

# %%
model = YOLO(pathToModel1)
model.val(data=data)

model = YOLO(pathToModel2)
model.val(data=data)
# Out:
# Ultralytics 8.3.189 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 1.6±1.8 ms, read: 138.4±40.1 MB/s, size: 629.1 KB)
# val: Scanning /home/jupyter/mnt/datasets/dataset_uav_fire/labels/val... 3609 images, 1916 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3609/3609 125.7it/s 28.7s
# WARNING ⚠️ val: Cache directory /home/jupyter/mnt/datasets/dataset_uav_fire/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 226/226 1.4it/s 2:43
#                    all       3609       1909      0.925      0.891      0.951      0.688
#                  smoke       1693       1909      0.925      0.891      0.951      0.688
# Speed: 0.2ms preprocess, 6.1ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val4
# ...
